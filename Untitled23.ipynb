# %% [markdown]
# <a href="https://colab.research.google.com/github/akulas1974-eng/machine-learning-bootcamp/blob/main/Untitled23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello colab')
# Out:
# Hello colab
