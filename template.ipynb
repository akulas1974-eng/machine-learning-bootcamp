# %% [markdown]
# <a href="https://colab.research.google.com/github/akulas1974-eng/machine-learning-bootcamp/blob/main/template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello colab')
# Out:
# Hello colab

# %%
# !pip install --upgrade scikit-learn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 28.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
# ...

# %%
import pandas as pd
import numpy as np
import sklearn

sklearn.__version__
# Out:
# '1.8.0'

# %%
data = {
    'size' : ['XL', 'L', 'M', 'L', 'M'],
    'color' : ['red', 'green', 'blue', 'green', 'red'],
    'gender' : ['female', 'male', 'male', 'female', 'female'],
    'price' : [199.0, 89.0, 99.0, 129.0, 79.0],
    'weight' : [500, 450, 300, 380, 410],
    'bought' : ['yes', 'no', 'yes', 'no', 'yes']
}

df_raw = pd.DataFrame(data=data)
df_raw
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0     500    yes
# 1    L  green    male   89.0     450     no
# 2    M   blue    male   99.0     300    yes
# 3    L  green  female  129.0     380     no
# 4    M    red  female   79.0     410    yes

# %%
df = df_raw.copy()
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-478559282.py in <cell line: 0>()
# ----> 1 df = df_raw.copy()
#       2 df.info()
#
# NameError: name 'df_raw' is not defined

# %%
for col in ['size', 'color', 'gender', 'bought']:
  df[col] = df[col].astype('category')
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2819077108.py in <cell line: 0>()
#       1 for col in ['size', 'color', 'gender', 'bought']:
# ----> 2   df[col] = df[col].astype('category')
#       3 df.info()
#
# NameError: name 'df' is not defined
